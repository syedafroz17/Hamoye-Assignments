# %% [markdown]
# <a href="https://colab.research.google.com/github/syedafroz17/Hamoye-Assignments/blob/main/StageB_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as no
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/energydata_complete.csv")

# %%
df.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
simple_linear_reg_df=df[['T2','T6',]].sample(15,random_state=2)

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
simple_linear_reg_df
# Out:
#               T2         T6
# 1117   17.426667  -4.238889
# 16275  22.760000  14.690000
# 13272  21.230000   8.926667
# 3160   21.100000   7.690000
# 19210  21.856667  10.800000
# 8260   17.356667   5.000000
# 12299  19.000000   5.300000
# 13505  22.700000  17.133333
# 12913  19.593333   7.545000
# 17788  21.890000   9.190000
# 17894  21.500000   5.160000
# 7665   19.142857   0.937500
# 10165  18.000000   0.200000
# 18809  22.400000  16.833333
# 8737   17.066667   1.900000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.drop(columns=["lights"], inplace=True)

# %%
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
normalised_df.head(5)
# Out:
#    Appliances    lights       T1      RH_1        T2      RH_2        T3  \
# 0    0.046729  0.428571  0.32735  0.566187  0.225345  0.684038  0.215188
# 1    0.046729  0.428571  0.32735  0.541326  0.225345  0.682140  0.215188
# 2    0.037383  0.428571  0.32735  0.530502  0.225345  0.679445  0.215188
# 3    0.037383  0.571429  0.32735  0.524080  0.225345  0.678414  0.215188
# 4    0.046729  0.571429  0.32735  0.531419  0.225345  0.676727  0.215188
#
#        RH_3        T4      RH_4  ...        T9      RH_9     T_out  \
# 0  0.746066  0.351351  0.764262  ...  0.223032  0.677290  0.372990
# 1  0.748871  0.351351  0.782437  ...  0.226500  0.678532  0.369239
# 2  0.755569  0.344745  0.778062  ...  0.219563  0.676049  0.365488
# 3  0.758685  0.341441  0.770949  ...  0.219563  0.671909  0.361736
# 4  0.758685  0.341441  0.762697  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
features_df=normalised_df.drop(columns=['date','lights'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ab9ada974190> in <cell line: 1>()
# ----> 1 features_df=normalised_df.drop(columns=['date','lights'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
features_df.head(10)
# Out:
#    Appliances    lights       T1      RH_1      RH_2        T3      RH_3  \
# 0    0.046729  0.428571  0.32735  0.566187  0.684038  0.215188  0.746066
# 1    0.046729  0.428571  0.32735  0.541326  0.682140  0.215188  0.748871
# 2    0.037383  0.428571  0.32735  0.530502  0.679445  0.215188  0.755569
# 3    0.037383  0.571429  0.32735  0.524080  0.678414  0.215188  0.758685
# 4    0.046729  0.571429  0.32735  0.531419  0.676727  0.215188  0.758685
# 5    0.037383  0.571429  0.32735  0.522980  0.675883  0.215188  0.755569
# 6    0.046729  0.714286  0.32735  0.515824  0.675883  0.215188  0.754012
# 7    0.046729  0.714286  0.32383  0.510137  0.675883  0.210203  0.754012
# 8    0.046729  0.571429  0.31679  0.511169  0.674009  0.210203  0.748871
# 9    0.056075  0.571429  0.32383  0.524723  0.673072  0.215188  0.752298
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# ...

# %%
heating_target=normalised_df['T2']

# %%
heating_target
# Out:
# 0        0.225345
# 1        0.225345
# 2        0.225345
# 3        0.225345
# 4        0.225345
#            ...
# 19730    0.711655
# 19731    0.701769
# 19732    0.692651
# 19733    0.677054
# 19734    0.666171
# Name: T2, Length: 19735, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df, heating_target,
                                                    test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_valueas=linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse=no.sqrt(mean_squared_error(y_test, predicted_valueas))
round(rmse,3)
# Out:
# 0.0

# %%
target=normalised_df['Appliances']

# %%
normalised_df.drop(columns=["lights"], inplace=True)

# %%
normalised_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df, target,
                                                    test_size=0.3, random_state=42)

# %%
normalised_df=pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_valueas=linear_model.predict(x_test)

# %%
mae=mean_absolute_error(y_test,predicted_valueas)
round(mae,3)
# Out:
# 0.0
